# %% [markdown]
# Описание датасета:
#
# rank: Position of the YouTube channel based on the number of subscribers
#
# Youtuber: Name of the YouTube channel
#
# subscribers: Number of subscribers to the channel
#
# video views: Total views across all videos on the channel
#
# category: Category or niche of the channel
#
# Title: Title of the YouTube channel
#
# uploads: Total number of videos uploaded on the channel
#
# Country: Country where the YouTube channel originates
#
# Abbreviation: Abbreviation of the country
#
# channel_type: Type of the YouTube channel (e.g., individual, brand)
#
# video_views_rank: Ranking of the channel based on total video views
#
# country_rank: Ranking of the channel based on the number of subscribers within its country
#
# channel_type_rank: Ranking of the channel based on its type (individual or brand)
#
# video_views_for_the_last_30_days: Total video views in the last 30 days
#
# lowest_monthly_earnings: Lowest estimated monthly earnings from the channel
#
# highest_monthly_earnings: Highest estimated monthly earnings from the channel
#
# lowest_yearly_earnings: Lowest estimated yearly earnings from the channel
#
# highest_yearly_earnings: Highest estimated yearly earnings from the channel
#
# subscribers_for_last_30_days: Number of new subscribers gained in the last 30 days
#
# created_year: Year when the YouTube channel was created
#
# created_month: Month when the YouTube channel was created
#
# created_date: Exact date of the YouTube channel’s creation
#
# Gross tertiary education enrollment (%): Percentage of the population enrolled in tertiary education in the country
#
# Population: Total population of the country
#
# Unemployment rate: Unemployment rate in the country
#
# Urban_population: Percentage of the population living in urban areas
#
# Latitude: Latitude coordinate of the country’s location
#
# Longitude: Longitude coordinate of the country’s location

# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

df = pd.read_csv('C:\\Users\\ilyak\\Desktop\\Python\\Python_projects\\Материалы\\Global YouTube Statistics.csv', encoding='windows-1251') 
df
# Out:
#      rank                    Youtuber  subscribers   video views  \
# 0       1                    T-Series    245000000  2.280000e+11
# 1       2              YouTube Movies    170000000  0.000000e+00
# 2       3                     MrBeast    166000000  2.836884e+10
# 3       4  Cocomelon - Nursery Rhymes    162000000  1.640000e+11
# 4       5                   SET India    159000000  1.480000e+11
# ..    ...                         ...          ...           ...
# 990   991               Natan por Aпї     12300000  9.029610e+09
# 991   992    Free Fire India Official     12300000  1.674410e+09
# 992   993                       Panda     12300000  2.214684e+09
# 993   994                 RobTopGames     12300000  3.741235e+08
# 994   995                Make Joke Of     12300000  2.129774e+09
#
#              category                       Title  uploads         Country  \
# 0               Music                    T-Series    20082           India
# ...

# %% [markdown]
# Подготовка данных к анализу
#
# Проверим типы данных

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 995 entries, 0 to 994
# Data columns (total 28 columns):
#  #   Column                                   Non-Null Count  Dtype
# ---  ------                                   --------------  -----
#  0   rank                                     995 non-null    int64
#  1   Youtuber                                 995 non-null    object
#  2   subscribers                              995 non-null    int64
#  3   video views                              995 non-null    float64
#  4   category                                 949 non-null    object
#  5   Title                                    995 non-null    object
#  6   uploads                                  995 non-null    int64
#  7   Country                                  873 non-null    object
#  8   Abbreviation                             873 non-null    object
#  9   channel_type                             965 non-null    object
# ...

# %%
df.describe()
# Out:
#             rank   subscribers   video views        uploads  video_views_rank  \
# count  995.00000  9.950000e+02  9.950000e+02     995.000000      9.940000e+02
# mean   498.00000  2.298241e+07  1.103954e+10    9187.125628      5.542489e+05
# std    287.37606  1.752611e+07  1.411084e+10   34151.352254      1.362782e+06
# min      1.00000  1.230000e+07  0.000000e+00       0.000000      1.000000e+00
# 25%    249.50000  1.450000e+07  4.288145e+09     194.500000      3.230000e+02
# 50%    498.00000  1.770000e+07  7.760820e+09     729.000000      9.155000e+02
# 75%    746.50000  2.460000e+07  1.355470e+10    2667.500000      3.584500e+03
# max    995.00000  2.450000e+08  2.280000e+11  301308.000000      4.057944e+06
#
#        country_rank  channel_type_rank  video_views_for_the_last_30_days  \
# count    879.000000         962.000000                      9.390000e+02
# mean     386.053470         745.719335                      1.756103e+08
# ...

# %% [markdown]
# Проверим значения на пропуски

# %%
df.isna().sum()
# Out:
# rank                                         0
# Youtuber                                     0
# subscribers                                  0
# video views                                  0
# category                                    46
# Title                                        0
# uploads                                      0
# Country                                    122
# Abbreviation                               122
# channel_type                                30
# video_views_rank                             1
# country_rank                               116
# channel_type_rank                           33
# video_views_for_the_last_30_days            56
# lowest_monthly_earnings                      0
# highest_monthly_earnings                     0
# lowest_yearly_earnings                       0
# highest_yearly_earnings                      0
# subscribers_for_last_30_days               337
# created_year                                 5
# ...

# %% [markdown]
# Заполним только те категории, которые нам понадобятся в дальнейшем анализе
#
# В столбцах category и channel_type пропуски можно заполнить, добавив новую категорию Other

# %%
df['category'] = df['category'].fillna('Other')
df['channel_type'] = df['channel_type'].fillna('Other')
df
# Out:
#      rank                    Youtuber  subscribers   video views  \
# 0       1                    T-Series    245000000  2.280000e+11
# 1       2              YouTube Movies    170000000  0.000000e+00
# 2       3                     MrBeast    166000000  2.836884e+10
# 3       4  Cocomelon - Nursery Rhymes    162000000  1.640000e+11
# 4       5                   SET India    159000000  1.480000e+11
# ..    ...                         ...          ...           ...
# 990   991               Natan por Aпї     12300000  9.029610e+09
# 991   992    Free Fire India Official     12300000  1.674410e+09
# 992   993                       Panda     12300000  2.214684e+09
# 993   994                 RobTopGames     12300000  3.741235e+08
# 994   995                Make Joke Of     12300000  2.129774e+09
#
#              category                       Title  uploads         Country  \
# 0               Music                    T-Series    20082           India
# ...

# %%
df.isna().sum()
# Out:
# rank                                         0
# Youtuber                                     0
# subscribers                                  0
# video views                                  0
# category                                     0
# Title                                        0
# uploads                                      0
# Country                                    122
# Abbreviation                               122
# channel_type                                 0
# video_views_rank                             1
# country_rank                               116
# channel_type_rank                           33
# video_views_for_the_last_30_days            56
# lowest_monthly_earnings                      0
# highest_monthly_earnings                     0
# lowest_yearly_earnings                       0
# highest_yearly_earnings                      0
# subscribers_for_last_30_days               337
# created_year                                 5
# ...

# %%
df[df['created_year'].isna()]
# Out:
#      rank               Youtuber  subscribers   video views        category  \
# 236   237            Chris Brown     25200000  1.552057e+10           Music
# 468   469  Good Mythical Morning     18300000  8.798045e+09   Entertainment
# 508   509     The Game Theorists     17600000  3.752347e+09          Gaming
# 735   736           LEGENDA FUNK     14500000  2.440718e+09           Music
# 762   763           Harry Styles     14400000  5.689224e+09  People & Blogs
#
#                    Title  uploads        Country Abbreviation channel_type  \
# 236           ChrisBrown        0            NaN          NaN        Other
# 468  Goodmythicalmorning        0            NaN          NaN        Other
# 508     TheGameTheorists        0      Australia           AU        Other
# 735          LegendaFUNK        0         Brazil           BR        Music
# 762          harrystyles        0  United States           US        Games
#
# ...

# %% [markdown]
# В столбцах created_year, created_month и created_date пропуски легко заполнить вручную, посмотрев информацию на YouTube в описании каналов

# %%
df.at[236, 'created_year'] = 2006
df.at[236, 'created_month'] = 'Dec'
df.at[236, 'created_date'] = 20

df.at[468, 'created_year'] = 2008
df.at[468, 'created_month'] = 'Sep'
df.at[468, 'created_date'] = 17

df.at[508, 'created_year'] = 2009
df.at[508, 'created_month'] = 'Aug'
df.at[508, 'created_date'] = 22

df.at[735, 'created_year'] = 2013
df.at[735, 'created_month'] = 'May'
df.at[735, 'created_date'] = 20

df.at[762, 'created_year'] = 2017
df.at[762, 'created_month'] = 'Mar'
df.at[762, 'created_date'] = 8

df[df['rank'].isin([237, 469, 509, 736, 763])]
# Out:
#      rank               Youtuber  subscribers   video views        category  \
# 236   237            Chris Brown     25200000  1.552057e+10           Music
# 468   469  Good Mythical Morning     18300000  8.798045e+09   Entertainment
# 508   509     The Game Theorists     17600000  3.752347e+09          Gaming
# 735   736           LEGENDA FUNK     14500000  2.440718e+09           Music
# 762   763           Harry Styles     14400000  5.689224e+09  People & Blogs
#
#                    Title  uploads        Country Abbreviation channel_type  \
# 236           ChrisBrown        0            NaN          NaN        Other
# 468  Goodmythicalmorning        0            NaN          NaN        Other
# 508     TheGameTheorists        0      Australia           AU        Other
# 735          LegendaFUNK        0         Brazil           BR        Music
# 762          harrystyles        0  United States           US        Games
#
# ...

# %% [markdown]
# Переходим к анализу

# %% [markdown]
# Задание 1.
#
# Разведывательный анализ данных

# %% [markdown]
# Распределение года создания каналов

# %%
plt.figure(figsize=(10, 6))
sns.boxplot(data=df, x='created_year')
plt.title('Распределение года создания каналов')
plt.xlabel('год создания канала')
plt.show()

# %% [markdown]
# По графику видно, что какой-то канал был создан в 1970 году, что не может быть верно, так как сам Youtube был создан в 14 февраля 2005 года

# %%
df[df['created_year'] == 1970]
# Out:
#      rank Youtuber  subscribers   video views         category    Title  \
# 101   102  YouTube     36300000  3.010785e+09  News & Politics  YouTube
#
#      uploads        Country Abbreviation   channel_type  ...  \
# 101      744  United States           US  Entertainment  ...
#
#      subscribers_for_last_30_days  created_year  created_month  created_date  \
# 101                      300000.0        1970.0            Jan           1.0
#
#      Gross tertiary education enrollment (%)   Population  Unemployment rate  \
# 101                                     88.2  328239523.0               14.7
#
#      Urban_population  Latitude  Longitude
# 101       270663028.0  37.09024 -95.712891
#
# [1 rows x 28 columns]

# %% [markdown]
# Оказалось, что это официальный канал YouTube и в описании даты создания не указано, поэтому изменим эту дату на дату создания YouTube

# %%
df.at[101, 'created_year'] = 2005
df.at[101, 'created_month'] = 'Feb'
df.at[101, 'created_date'] = 14

df.loc[[101]]
# Out:
#      rank Youtuber  subscribers   video views         category    Title  \
# 101   102  YouTube     36300000  3.010785e+09  News & Politics  YouTube
#
#      uploads        Country Abbreviation   channel_type  ...  \
# 101      744  United States           US  Entertainment  ...
#
#      subscribers_for_last_30_days  created_year  created_month  created_date  \
# 101                      300000.0        2005.0            Feb          14.0
#
#      Gross tertiary education enrollment (%)   Population  Unemployment rate  \
# 101                                     88.2  328239523.0               14.7
#
#      Urban_population  Latitude  Longitude
# 101       270663028.0  37.09024 -95.712891
#
# [1 rows x 28 columns]

# %% [markdown]
# Построим график рапсределения

# %%
sns.set_style('whitegrid')

plt.figure(figsize=(10, 6))
sns.histplot(data=df, x='created_year', kde=True)
plt.xticks(range(2005, 2023))
plt.title('Distribution of the created year')
plt.xlabel('Year')
plt.ylabel('Number of channels')
plt.show()

# %% [markdown]
# Из графика видно, что большинство каналов создано в 2013-2014 годах

# %%
plt.figure(figsize=(10, 6))
sns.boxplot(data=df, x='created_year')
plt.xticks(range(2005, 2023))
plt.xlabel('Created year')
plt.show()

# %% [markdown]
# Из графика видно, что 50% каналов была создана в 2009-2016 годах.
#
# Медиана составляет 2013 год

# %% [markdown]
# Топ 10 каналов по подписчикам

# %%
top10_sub = df.sort_values('subscribers', ascending=False).head(10)
top10_sub['subscribers'] = top10_sub['subscribers'] / 10**6

plt.figure(figsize=(10, 6))
sns.barplot(data=top10_sub, x='Youtuber', y='subscribers')
plt.xticks(rotation=45, ha='right')
plt.title('Top 10 YouTube Channels by Subscribers')
plt.xlabel('Channel')
plt.ylabel('Number of subscribers (Millions)')
plt.show()

# %% [markdown]
# Число каналов по категориям

# %%
top_category = df.value_counts('category').to_frame().reset_index()
top_category.columns = ['category', 0]

plt.figure(figsize=(12, 6))
sns.barplot(data=top_category, x='category', y=0)
plt.xticks(rotation=45, ha='right')
plt.title('Categorys of channels')
plt.xlabel('Category')
plt.ylabel('Number of channels')
plt.show()

# %% [markdown]
# Топ 10 каналов по просмотрам

# %%
top10_views = df.sort_values('video views', ascending=False).head(10)
top10_views['video views'] = top10_views['video views'] / 10**9

plt.figure(figsize=(10, 6))
sns.barplot(data=top10_views, x='Youtuber', y='video views')
plt.xticks(rotation=45, ha='right')
plt.title('Top 10 YouTube Channels by Views')
plt.xlabel('Channel')
plt.ylabel('Number of views (Billions)')
plt.show()

# %% [markdown]
# Топ 10 каналов по количеству видео

# %%
top10_uploads = df.sort_values('uploads', ascending=False).head(10)

plt.figure(figsize=(10, 6))
sns.barplot(data=top10_uploads, x='Youtuber', y='uploads')
plt.xticks(rotation=45, ha='right')
plt.title('Top 10 YouTube Channels by Uploads')
plt.xlabel('Channel')
plt.ylabel('Number of uploads')
plt.show()

# %% [markdown]
# Топ 10 стран по количеству каналов

# %%
top10_country = df.value_counts('Country').to_frame().reset_index().head(10)

top10_country.columns = ['Country', 0]

plt.figure(figsize=(10, 6))
sns.barplot(data=top10_country, x='Country', y=0)
plt.xticks(rotation=45, ha='right')
plt.title('Top 10 Countries by number of Channels')
plt.xlabel('Country')
plt.ylabel('Number of channels')
plt.show()

# %% [markdown]
# Топ 10 каналов по ежемесячным доходам

# %%
#В датасете даны минимальные и максимальные предполагаемые месячные доходы. Я взял среднее 
df_earnings = df[['Youtuber']].copy()
df_earnings['mean_monthly_earnings'] = df[['lowest_monthly_earnings', 'highest_monthly_earnings']].mean(axis=1) / 10**6
df_earnings
# Out:
#                        Youtuber  mean_monthly_earnings
# 0                      T-Series           4.782300e+00
# 1                YouTube Movies           2.500000e-08
# 2                       MrBeast           2.868500e+00
# 3    Cocomelon - Nursery Rhymes           4.196900e+00
# 4                     SET India           3.877950e+00
# ..                          ...                    ...
# 990               Natan por Aпї           1.169050e+00
# 991    Free Fire India Official           1.375500e-01
# 992                       Panda           1.425000e-04
# 993                 RobTopGames           8.234000e-03
# 994                Make Joke Of           5.100000e-02
#
# [995 rows x 2 columns]

# %%
top10_earnings = df_earnings.sort_values('mean_monthly_earnings', ascending=False).head(10)

plt.figure(figsize=(10, 6))
sns.barplot(data=top10_earnings, x='Youtuber', y='mean_monthly_earnings')
plt.xticks(rotation=45, ha='right')
plt.title('Top 10 YouTube Channels by monthly earnings')
plt.xlabel('Channel')
plt.ylabel('Mean monthly earnings (millions)')
plt.show()

# %%
plt.figure(figsize=(10, 8))
sns.heatmap(df.iloc[:, :-2].corr(numeric_only=True))
plt.xticks(rotation=45, ha='right')
plt.show()

# %% [markdown]
# Задание 2. Корреляционный анализ

# %% [markdown]
# Оставьте два коррелирующих столбца: "subscribers" и"video views".

# %%
new_df = df[['subscribers', 'video views']]
new_df
# Out:
#      subscribers   video views
# 0      245000000  2.280000e+11
# 1      170000000  0.000000e+00
# 2      166000000  2.836884e+10
# 3      162000000  1.640000e+11
# 4      159000000  1.480000e+11
# ..           ...           ...
# 990     12300000  9.029610e+09
# 991     12300000  1.674410e+09
# 992     12300000  2.214684e+09
# 993     12300000  3.741235e+08
# 994     12300000  2.129774e+09
#
# [995 rows x 2 columns]

# %% [markdown]
# Отфильтруйте данные - уберите те строки, где кол-во просмотров равно нулю.

# %%
new_df = new_df[new_df['video views'] != 0]
new_df
# Out:
#      subscribers   video views
# 0      245000000  2.280000e+11
# 2      166000000  2.836884e+10
# 3      162000000  1.640000e+11
# 4      159000000  1.480000e+11
# 6      112000000  9.324704e+10
# ..           ...           ...
# 990     12300000  9.029610e+09
# 991     12300000  1.674410e+09
# 992     12300000  2.214684e+09
# 993     12300000  3.741235e+08
# 994     12300000  2.129774e+09
#
# [987 rows x 2 columns]

# %%
sns.regplot(data=new_df, x='subscribers', y='video views', line_kws={'color': 'red'})
# Out:
# <Axes: xlabel='subscribers', ylabel='video views'>

# %% [markdown]
# Рассчитайте коэффициент корреляции Пирсона.

# %%
from scipy.stats import pearsonr
corr, _ = pearsonr(new_df['subscribers'], new_df['video views'])
print('Pearsons correlation: %.3f' % corr)
# Out:
# Pearsons correlation: 0.824

# %% [markdown]
# Определить "video views" как признак Х, а "subscribers" - как целевую переменную.
# Разделить выборку на тестовую и тренировочную.
# Построить модель линейной регрессии.
# Рассчитать точность модели на тестовой выборке.

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import Lasso
from sklearn.model_selection import RandomizedSearchCV
from scipy.stats import loguniform

# Обучающие данные
X = new_df.drop('subscribers', axis=1)
y = new_df['subscribers']

# Разделение данных на обучающую и валидационную выборку
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

# Скалярование данных
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# Создание модели Lasso
model = Lasso()

# Параметры RandomizedSearchCV
param_dist = {
    'alpha': loguniform(1e-7, 1e-2),
    'max_iter': [5000, 10000]
}

random_search = RandomizedSearchCV(estimator=model, param_distributions=param_dist,
                                   n_iter=10, cv=10, verbose=2)
random_search.fit(X_train_scaled, y_train)

# Оценка модели на валидационных данных
y_pred_test = random_search.best_estimator_.predict(X_test_scaled)
# Out:
# Fitting 10 folds for each of 10 candidates, totalling 100 fits
# [CV] END ........alpha=1.3783875478297228e-06, max_iter=5000; total time=   0.0s
# [CV] END ........alpha=1.3783875478297228e-06, max_iter=5000; total time=   0.0s
# [CV] END ........alpha=1.3783875478297228e-06, max_iter=5000; total time=   0.0s
# [CV] END ........alpha=1.3783875478297228e-06, max_iter=5000; total time=   0.0s
# [CV] END ........alpha=1.3783875478297228e-06, max_iter=5000; total time=   0.0s
# [CV] END ........alpha=1.3783875478297228e-06, max_iter=5000; total time=   0.0s
# [CV] END ........alpha=1.3783875478297228e-06, max_iter=5000; total time=   0.0s
# [CV] END ........alpha=1.3783875478297228e-06, max_iter=5000; total time=   0.0s
# [CV] END ........alpha=1.3783875478297228e-06, max_iter=5000; total time=   0.0s
# [CV] END ........alpha=1.3783875478297228e-06, max_iter=5000; total time=   0.0s
# [CV] END ..........alpha=2.08667689313333e-07, max_iter=5000; total time=   0.0s
# ...

# %%
print("Оценка модели на тестовых данных:", random_search.best_score_)
# Out:
# Оценка модели на тестовых данных: 0.5543284415441316

# %% [markdown]
# Предсказайте значения "subscribers".

# %%
subscribers_pred = random_search.best_estimator_.predict(X_test_scaled)
subscribers_pred
# Out:
# array([1.84080732e+07, 3.78001936e+07, 2.52647622e+07, 2.48018542e+07,
#        1.45575555e+07, 4.64085690e+07, 1.51334742e+07, 3.81346989e+07,
#        1.40411059e+07, 1.61651735e+07, 3.36405485e+07, 2.86327741e+07,
#        2.24773515e+07, 2.48770898e+07, 3.31891604e+07, 1.69631637e+07,
#        2.39326979e+07, 1.40406820e+07, 1.35424253e+07, 2.17566026e+07,
#        1.65238273e+07, 2.04178863e+07, 1.93457763e+07, 1.82311310e+07,
#        1.48469576e+07, 1.50777103e+07, 2.66931071e+07, 2.13509234e+07,
#        3.47711945e+07, 1.87789547e+07, 3.20446452e+07, 1.79407561e+07,
#        1.62310594e+07, 1.71007334e+07, 2.72801005e+07, 1.29722598e+07,
#        1.87473254e+07, 1.48108669e+07, 6.79639537e+07, 3.05992926e+07,
#        8.48098347e+07, 3.47156563e+07, 1.80670674e+07, 1.66682949e+08,
#        2.76940042e+07, 1.61615249e+07, 2.36791310e+07, 1.77783067e+07,
#        1.36199950e+07, 1.65063470e+07, 1.52127204e+07, 1.60509830e+07,
# ...

# %% [markdown]
# Если не убирать нули в данных

# %%
zero_df = df[['subscribers', 'video views']]
zero_df
# Out:
#      subscribers   video views
# 0      245000000  2.280000e+11
# 1      170000000  0.000000e+00
# 2      166000000  2.836884e+10
# 3      162000000  1.640000e+11
# 4      159000000  1.480000e+11
# ..           ...           ...
# 990     12300000  9.029610e+09
# 991     12300000  1.674410e+09
# 992     12300000  2.214684e+09
# 993     12300000  3.741235e+08
# 994     12300000  2.129774e+09
#
# [995 rows x 2 columns]

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import Lasso
from sklearn.model_selection import RandomizedSearchCV
from scipy.stats import loguniform

# Обучающие данные
X = zero_df.drop('subscribers', axis=1)
y = zero_df['subscribers']

# Разделение данных на обучающую и валидационную выборку
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

# Скалярование данных
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# Создание модели Lasso
model = Lasso()

# Параметры RandomizedSearchCV
param_dist = {
    'alpha': loguniform(1e-7, 1e-2),
    'max_iter': [5000, 10000]
}

random_search = RandomizedSearchCV(estimator=model, param_distributions=param_dist,
                                   n_iter=10, cv=10, verbose=2)
random_search.fit(X_train_scaled, y_train)

# Оценка модели на валидационных данных
y_pred_test = random_search.best_estimator_.predict(X_test_scaled)
# Out:
# Fitting 10 folds for each of 10 candidates, totalling 100 fits
# [CV] END ........alpha=0.0012599399227821643, max_iter=10000; total time=   0.0s
# [CV] END ........alpha=0.0012599399227821643, max_iter=10000; total time=   0.0s
# [CV] END ........alpha=0.0012599399227821643, max_iter=10000; total time=   0.0s
# [CV] END ........alpha=0.0012599399227821643, max_iter=10000; total time=   0.0s
# [CV] END ........alpha=0.0012599399227821643, max_iter=10000; total time=   0.0s
# [CV] END ........alpha=0.0012599399227821643, max_iter=10000; total time=   0.0s
# [CV] END ........alpha=0.0012599399227821643, max_iter=10000; total time=   0.0s
# [CV] END ........alpha=0.0012599399227821643, max_iter=10000; total time=   0.0s
# [CV] END ........alpha=0.0012599399227821643, max_iter=10000; total time=   0.0s
# [CV] END ........alpha=0.0012599399227821643, max_iter=10000; total time=   0.0s
# [CV] END ........alpha=1.9086570501898215e-05, max_iter=5000; total time=   0.0s
# ...

# %%
print("Оценка модели на тестовых данных:", random_search.best_score_)
# Out:
# Оценка модели на тестовых данных: 0.48856991071652506

# %% [markdown]
# Можно сделать вывод, что при убирании нулей в данных оценка модели ухудшилась

# %% [markdown]
# Задание 3. Классификация

# %% [markdown]
# Определите две самые популярные категории канала и отфильтруйте по ним набор данных.
#
# В качестве признаков используйте следующие столбцы: [‘video views’, ‘subscribers’, ‘uploads’]

# %%
top_two = df.groupby('category')[['video views', 'subscribers', 'uploads']].sum().nlargest(2, 'video views')
top_two
# Out:
#                 video views  subscribers  uploads
# category
# Music          3.121478e+12   5195000000   471773
# Entertainment  2.527739e+12   5158200000  2869944

# %%
filtered_df = df[df['category'].isin(top_two.index)]
filtered_df
# Out:
#      rank                  Youtuber  subscribers   video views       category  \
# 0       1                  T-Series    245000000  2.280000e+11          Music
# 2       3                   MrBeast    166000000  2.836884e+10  Entertainment
# 9      10             Vlad and Niki     98900000  7.718017e+10  Entertainment
# 10     11         Zee Music Company     96700000  5.785629e+10          Music
# 17     18                 BANGTANTV     75600000  2.082699e+10          Music
# ..    ...                       ...          ...           ...            ...
# 976   977            SAAIHALILINTAR     12400000  1.113066e+09  Entertainment
# 978   979  Heidi and Zidane HZHtube     12400000  4.021409e+09  Entertainment
# 982   983           DisneyChannelUK     12400000  1.260749e+10          Music
# 987   988             Avril Lavigne     12400000  6.202090e+09          Music
# 989   990                 Migos ATL     12400000  6.993406e+09          Music
#
# ...

# %%
filtered_df_new = filtered_df[filtered_df['video views']!= 0]
filtered_df_new
# Out:
#      rank                  Youtuber  subscribers   video views       category  \
# 0       1                  T-Series    245000000  2.280000e+11          Music
# 2       3                   MrBeast    166000000  2.836884e+10  Entertainment
# 9      10             Vlad and Niki     98900000  7.718017e+10  Entertainment
# 10     11         Zee Music Company     96700000  5.785629e+10          Music
# 17     18                 BANGTANTV     75600000  2.082699e+10          Music
# ..    ...                       ...          ...           ...            ...
# 976   977            SAAIHALILINTAR     12400000  1.113066e+09  Entertainment
# 978   979  Heidi and Zidane HZHtube     12400000  4.021409e+09  Entertainment
# 982   983           DisneyChannelUK     12400000  1.260749e+10          Music
# 987   988             Avril Lavigne     12400000  6.202090e+09          Music
# 989   990                 Migos ATL     12400000  6.993406e+09          Music
#
# ...

# %%
filtered_df_new.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 443 entries, 0 to 989
# Data columns (total 28 columns):
#  #   Column                                   Non-Null Count  Dtype
# ---  ------                                   --------------  -----
#  0   rank                                     443 non-null    int64
#  1   Youtuber                                 443 non-null    object
#  2   subscribers                              443 non-null    int64
#  3   video views                              443 non-null    float64
#  4   category                                 443 non-null    object
#  5   Title                                    443 non-null    object
#  6   uploads                                  443 non-null    int64
#  7   Country                                  394 non-null    object
#  8   Abbreviation                             394 non-null    object
#  9   channel_type                             443 non-null    object
# ...

# %%
filtered_df_new = filtered_df_new[['category', 'video views', 'subscribers', 'uploads']]
filtered_df_new
# Out:
#           category   video views  subscribers  uploads
# 0            Music  2.280000e+11    245000000    20082
# 2    Entertainment  2.836884e+10    166000000      741
# 9    Entertainment  7.718017e+10     98900000      574
# 10           Music  5.785629e+10     96700000     8548
# 17           Music  2.082699e+10     75600000     2281
# ..             ...           ...          ...      ...
# 976  Entertainment  1.113066e+09     12400000      409
# 978  Entertainment  4.021409e+09     12400000      813
# 982          Music  1.260749e+10     12400000     4422
# 987          Music  6.202090e+09     12400000      205
# 989          Music  6.993406e+09     12400000       99
#
# [443 rows x 4 columns]

# %%
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score

# Преобразование целевой переменной с помощью LabelEncoder
le = LabelEncoder()
filtered_df_new['category'] = le.fit_transform(filtered_df_new['category'])

# Разделение выборки на тренировочную и тестовую
X = filtered_df_new.drop(['category'], axis=1)
y = filtered_df_new['category']
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=13)

# Постройте модель логистической регрессии
model = LogisticRegression()
model.fit(X_train, y_train)

# Рассчитайте точность модели на тестовой выборке
y_pred = model.predict(X_test)
accuracy = accuracy_score(y_test, y_pred)
print(f"Точность модели: {accuracy:.2f}")
# Out:
# Точность модели: 0.64
# C:\Users\ilyak\AppData\Local\Temp\ipykernel_16716\382953437.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_df_new['category'] = le.fit_transform(filtered_df_new['category'])

# %%
# !pip install liblinear
# Out:
# ...
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# ...
#   Created wheel for liblinear: filename=liblinear-2.11.2-py3-none-any.whl size=8526 sha256=b076c542d9773f3948473cdd27d9be82f0f36f542d7643e2d7bec427d22852b8
#   Stored in directory: c:\users\ilyak\appdata\local\pip\cache\wheels\b3\cf\e5\8f89b4e4ca55fa4b6af63f461eb0bec8445cd92953dd6531f2
# Successfully built liblinear
# ...

# %%
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split, KFold
from sklearn.linear_model import LogisticRegressionCV, LogisticRegression
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report, ConfusionMatrixDisplay

# Преобразование целевой переменной с помощью LabelEncoder
le = LabelEncoder()
filtered_df_new['category'] = le.fit_transform(filtered_df_new['category'])
# Разделение выборки на тренировочную и тестовую
X = filtered_df_new.drop(['category'], axis=1)
y = filtered_df_new['category']
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.1, random_state=13)

# Создание логистической регрессии с кросс-валидацией и использованием liblinear
kfolds = KFold(n_splits=10, shuffle=True)
log_model = LogisticRegressionCV(Cs=np.logspace(-5, 8, 11), penalty='l1', solver='liblinear', cv=kfolds)

# Обучение модели на тренировочной выборке
log_model.fit(X_train, y_train)

# Предсказание категорий на тестовой выборке
y_pred = log_model.predict(X_test)
accuracy = accuracy_score(y_test, y_pred)
print(f"Точность модели: {accuracy:.2f}")
# Out:
# Точность модели: 0.73
# C:\Users\ilyak\AppData\Local\Temp\ipykernel_16716\1252151143.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_df_new['category'] = le.fit_transform(filtered_df_new['category'])

# %% [markdown]
# Оценка модели

# %%
confusion_matrix(y_test, y_pred)
# Out:
# array([[18,  6],
#        [ 6, 15]], dtype=int64)

# %%
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.75      0.75      0.75        24
#            1       0.71      0.71      0.71        21
#
#     accuracy                           0.73        45
#    macro avg       0.73      0.73      0.73        45
# weighted avg       0.73      0.73      0.73        45

# %% [markdown]
# если считать с нулями

# %%
filtered_df = filtered_df[['category', 'video views', 'subscribers', 'uploads']]
filtered_df
# Out:
#           category   video views  subscribers  uploads
# 0            Music  2.280000e+11    245000000    20082
# 2    Entertainment  2.836884e+10    166000000      741
# 9    Entertainment  7.718017e+10     98900000      574
# 10           Music  5.785629e+10     96700000     8548
# 17           Music  2.082699e+10     75600000     2281
# ..             ...           ...          ...      ...
# 976  Entertainment  1.113066e+09     12400000      409
# 978  Entertainment  4.021409e+09     12400000      813
# 982          Music  1.260749e+10     12400000     4422
# 987          Music  6.202090e+09     12400000      205
# 989          Music  6.993406e+09     12400000       99
#
# [443 rows x 4 columns]

# %%
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score

# Преобразование целевой переменной с помощью LabelEncoder
le = LabelEncoder()
filtered_df['category'] = le.fit_transform(filtered_df['category'])

# Разделение выборки на тренировочную и тестовую
X = filtered_df.drop(['category'], axis=1)
y = filtered_df['category']
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=13)

# Постройте модель логистической регрессии
model = LogisticRegression()
model.fit(X_train, y_train)

# Рассчитайте точность модели на тестовой выборке
y_pred = model.predict(X_test)
accuracy = accuracy_score(y_test, y_pred)
print(f"Точность модели: {accuracy:.2f}")
# Out:
# Точность модели: 0.64
# C:\Users\ilyak\AppData\Local\Temp\ipykernel_16716\3689197530.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_df['category'] = le.fit_transform(filtered_df['category'])

# %%
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split, KFold
from sklearn.linear_model import LogisticRegressionCV, LogisticRegression
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report, ConfusionMatrixDisplay

# Преобразование целевой переменной с помощью LabelEncoder
le = LabelEncoder()
filtered_df['category'] = le.fit_transform(filtered_df['category'])
# Разделение выборки на тренировочную и тестовую
X = filtered_df.drop(['category'], axis=1)
y = filtered_df['category']
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=13)

# Создание логистической регрессии с кросс-валидацией и использованием liblinear
kfolds = KFold(n_splits=10, shuffle=True)
log_model = LogisticRegressionCV(Cs=np.logspace(-5, 5, 11), penalty='l1', solver='liblinear', cv=kfolds)

# Обучение модели на тренировочной выборке
log_model.fit(X_train, y_train)

# Предсказание категорий на тестовой выборке
y_pred = log_model.predict(X_test)
accuracy = accuracy_score(y_test, y_pred)
print(f"Точность модели: {accuracy:.2f}")
# Out:
# Точность модели: 0.65
# C:\Users\ilyak\AppData\Local\Temp\ipykernel_16716\1162969627.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_df['category'] = le.fit_transform(filtered_df['category'])

# %%
confusion_matrix(y_test, y_pred)
# Out:
# array([[26, 24],
#        [ 7, 32]], dtype=int64)

# %%
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.79      0.52      0.63        50
#            1       0.57      0.82      0.67        39
#
#     accuracy                           0.65        89
#    macro avg       0.68      0.67      0.65        89
# weighted avg       0.69      0.65      0.65        89

# %% [markdown]
# Как мы можем наблюдать из сравнения двух моделей: в данном случае модель логистической регрессии, в которую подавались данные без нулей показала гораздо большую точность, чем модель с нулями.
#
# Модель без нулей:
#
#               precision    recall  f1-score   support
#
#            0       0.75      0.75      0.75        24
#            1       0.71      0.71      0.71        21
#
#     accuracy                           0.73        45
#    macro avg       0.73      0.73      0.73        45
# weighted avg       0.73      0.73      0.73        45
#
#
# Модель с нулями:
#
#               precision    recall  f1-score   support
#
#            0       0.79      0.52      0.63        50
#            1       0.57      0.82      0.67        39
#
#     accuracy                           0.65        89
#    macro avg       0.68      0.67      0.65        89
# weighted avg       0.69      0.65      0.65        89
